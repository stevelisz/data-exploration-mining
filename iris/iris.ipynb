# %%
import pandas as pd
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url, header=None, names=["Sepal Length", "Sepal Width",
"Petal Length", "Petal Width",
"Name"])

# %%
df
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width            Name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#1.1
print(df.head(5))
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#4 features are there and they are numeric.
#minimum value, maximum value, mean, standard deviation, count, and 25:50:75% percentiles.
df['Sepal Length'].mean()
# Out:
# 5.843333333333335

# %%
df['Sepal Length'].min()
# Out:
# 4.3

# %%
df['Sepal Length'].max()
# Out:
# 7.9

# %%
df['Sepal Length'].std()
# Out:
# 0.8280661279778629

# %%
df['Sepal Length'].count()
# Out:
# 150

# %%
df['Sepal Length'].quantile([.25, .5, .75])
# Out:
# 0.25    5.1
# 0.50    5.8
# 0.75    6.4
# Name: Sepal Length, dtype: float64

# %%
df['Sepal Width'].mean()
# Out:
# 3.0540000000000007

# %%
df['Sepal Width'].min()
# Out:
# 2.0

# %%
df['Sepal Width'].max()
# Out:
# 4.4

# %%
df['Sepal Width'].std()
# Out:
# 0.4335943113621737

# %%
df['Sepal Width'].count()
# Out:
# 150

# %%
df['Sepal Width'].quantile([.25, .5, .75])
# Out:
# 0.25    2.8
# 0.50    3.0
# 0.75    3.3
# Name: Sepal Width, dtype: float64

# %%
df['Petal Length'].mean()
# Out:
# 3.7586666666666693

# %%
df['Petal Length'].min()
# Out:
# 1.0

# %%
df['Petal Length'].max()
# Out:
# 6.9

# %%
df['Petal Length'].std()
# Out:
# 1.7644204199522617

# %%
df['Petal Length'].count()
# Out:
# 150

# %%
df['Petal Length'].quantile([.25,.5,.75])
# Out:
# 0.25    1.60
# 0.50    4.35
# 0.75    5.10
# Name: Petal Length, dtype: float64

# %%
df['Petal Width'].mean()
# Out:
# 1.1986666666666672

# %%
df['Petal Width'].max()
# Out:
# 2.5

# %%
df['Petal Width'].min()
# Out:
# 0.1

# %%
df['Petal Width'].std()
# Out:
# 0.7631607417008414

# %%
df['Petal Width'].count()
# Out:
# 150

# %%
df['Petal Width'].quantile([.25,.5,.75])
# Out:
# 0.25    0.3
# 0.50    1.3
# 0.75    1.8
# Name: Petal Width, dtype: float64

# %%
#1.2 Data Visualization
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sepal Length'}>,
#         <AxesSubplot:title={'center':'Sepal Width'}>],
#        [<AxesSubplot:title={'center':'Petal Length'}>,
#         <AxesSubplot:title={'center':'Petal Width'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
#2
import pandas as pd
pd.set_option("display.max_columns", 100)
url = "https://raw.githubusercontent.com/cs6220/cs6220.spring2019/master/data/AmesHousing.txt"
df2 = pd.read_csv(url, sep="\t")

# %%
df2
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df2.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
df_missing = df2.isna().sum()

# %%
df_missing
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
count = 0
for i in df_missing:
    if(i > 0):
        count += 1
count
#2.1.1 there are 27 features have missing values.
# Out:
# 27

# %%
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
df2
for each_column in df2:
    if(is_string_dtype(df2[each_column])):
        df2[each_column] = df2[each_column].fillna("Missing")
        continue
df2
#2.1.2
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
for each_column in df2:
    if(is_numeric_dtype(df2[each_column])):
        df2[each_column] = df2[each_column].interpolate(method ='linear')
        continue
df2

#2.1.3
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL          49.5      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df2.boxplot(figsize=(40,40))
# Out:
# <AxesSubplot:>

# %%
#2.2.1
from sklearn import preprocessing
for each_column in df2:
    if(is_numeric_dtype(df2[each_column])):
        df2[each_column] = preprocessing.scale(df2[each_column])
        continue
df2
# Out:
#          Order       PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0    -1.731460 -0.997164    -0.877005        RL      3.128744  2.744381
# 1    -1.730277 -0.996904    -0.877005        RH      0.459721  0.187097
# 2    -1.729095 -0.996899    -0.877005        RL      0.503475  0.522814
# 3    -1.727913 -0.996888    -0.877005        RL      1.028529  0.128458
# 4    -1.726731 -0.992903     0.061285        RL      0.197194  0.467348
# ...        ...       ...          ...       ...           ...       ...
# 2925  1.726731  1.106582     0.530430        RL     -1.421722 -0.280621
# 2926  1.727913  1.106588    -0.877005        RL     -0.874791 -0.160296
# 2927  1.729095  1.107245     0.647716        RL     -0.327860  0.037199
# 2928  1.730277  1.110954    -0.877005        RL      0.328457 -0.017506
# 2929  1.731460  1.111225     0.061285        RL      0.197194 -0.066118
#
#      Street    Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# ...

# %%
#2.2.2
df2.boxplot(figsize=(40,40))
# Out:
# <AxesSubplot:>

# %%
#As can be seen the circle is way more spread out than the plot before standardization. The size of the box
#is also different for each feature after standardization. That means the data is standardized so there 
#will be unit variance and zero mean. As we can see, feature order has the outlier furtherst from mean before
#standardization, misc val has the outlier furtherst from the mean after standardization.

# %%
#2.3
from sklearn import feature_selection

# %%
import numpy as np
lst = []
for each_column in df2:
    if(is_numeric_dtype(df2[each_column])):
        info = feature_selection.mutual_info_regression(np.array(df2['SalePrice']).reshape(-1, 1), np.array(df2[each_column]))
        lst.append((each_column,info[0]))
        continue
lst
#2.3.1
# Out:
# [('Order', 0.2801706744223402),
#  ('PID', 0.25854132735063207),
#  ('MS SubClass', 0.2919070504287342),
#  ('Lot Frontage', 0.2119939461592475),
#  ('Lot Area', 0.16583410425653433),
#  ('Overall Qual', 0.5825435113000177),
#  ('Overall Cond', 0.12764017820979845),
#  ('Year Built', 0.4015317010407502),
#  ('Year Remod/Add', 0.29970214533715556),
#  ('Mas Vnr Area', 0.18016519883074888),
#  ('BsmtFin SF 1', 0.18482888705398892),
#  ('BsmtFin SF 2', 0.007376205191999219),
#  ('Bsmt Unf SF', 0.11943517376953228),
#  ('Total Bsmt SF', 0.3934122069277981),
#  ('1st Flr SF', 0.3702670315101164),
#  ('2nd Flr SF', 0.20453507027143836),
#  ('Low Qual Fin SF', 0),
#  ('Gr Liv Area', 0.4948310899955004),
#  ('Bsmt Full Bath', 0.04222002972196126),
#  ('Bsmt Half Bath', 0.016202246211388882),
#  ('Full Bath', 0.25384032471210993),
#  ('Half Bath', 0.05740641085230358),
#  ('Bedroom AbvGr', 0.050659790140790584),
#  ('Kitchen AbvGr', 0.021453255727163167),
# ...

# %%
lst.sort(key = lambda x: x[1],reverse=True)

# %%
#2.3.2
lst
# Out:
# [('SalePrice', 5.928657412298004),
#  ('Overall Qual', 0.5825435113000177),
#  ('Gr Liv Area', 0.4948310899955004),
#  ('Garage Area', 0.4183346616124668),
#  ('Year Built', 0.4015317010407502),
#  ('Total Bsmt SF', 0.3934122069277981),
#  ('Garage Cars', 0.3779502460178614),
#  ('1st Flr SF', 0.3702670315101164),
#  ('Garage Yr Blt', 0.30329728441010495),
#  ('Year Remod/Add', 0.29970214533715556),
#  ('MS SubClass', 0.2919070504287342),
#  ('Order', 0.2801706744223402),
#  ('PID', 0.25854132735063207),
#  ('Full Bath', 0.25384032471210993),
#  ('Lot Frontage', 0.2119939461592475),
#  ('2nd Flr SF', 0.20453507027143836),
#  ('Fireplaces', 0.18721751184267177),
#  ('TotRms AbvGrd', 0.18710691739004215),
#  ('BsmtFin SF 1', 0.18482888705398892),
#  ('Open Porch SF', 0.18471865073629434),
#  ('Mas Vnr Area', 0.18016519883074888),
#  ('Lot Area', 0.16583410425653433),
#  ('Overall Cond', 0.12764017820979845),
#  ('Bsmt Unf SF', 0.11943517376953228),
# ...

# %%
#As we can see, except for salePrice itself, the top 5 numeric features ranked by mutual information are
#Overall Qual, Gr Liv Area, Garage Area, Year Built, Total Bsmt SF

# %%
#2.3.3
#I would expect the price goes up if these top ranked values go up and vice versa. Because according to
#the mutual information formula, if the MI goes up, joint probability will also go up.
